# %% [markdown]
# # 03a08 At Only -- Top defense features

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pickle 
import time 

from scipy import stats

from xgboost import XGBClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
# from sklearn.inspection import permutation_importance

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white")

from collections import Counter

import sys; sys.path.insert(0, '..') # add parent folder path where lib folder is
from atbotml.custom_fuctions import *

# %% [markdown]
# ## Notebook parameters

# %%
nb_id = f'03a08'
nb_long_id = f'{nb_id}_defense'
num_classes = 10
random_state = 42

# %% [markdown]
# ## Load data

# %%
# load complete training dataframe
df = pd.read_pickle("./01_AtBot_data.pkl")
print(f"Number of data samples: {len(df)}")
print(f"Number of features: {len(df.columns)-6}")

# extract feature names from RNASeq data
gene_names = list(df)[6:29107]

# Arabidopsis only feature gene set
n_At = 20340
At_list = gene_names[0:n_At]
print(f"Number of At genes: {n_At}")
df
# Out:
# Number of data samples: 1092
# Number of features: 29101
# Number of At genes: 20340
#         Index      LibraryID HostGenoType  Sample  Isolate     Lesion  \
# 0      coi1_1    coi.1.G1E.1         coi1       1  1.01.01  36.590004
# 1      coi1_1    coi.1.G1F.1         coi1       1  1.01.01  36.590004
# 2      coi1_1    coi.1.G2F.1         coi1       1  1.01.01  36.590004
# 3      coi1_1    coi.1.G2E.1         coi1       1  1.01.01  36.590004
# 4     coi1_10   coi.1.G2E.10         coi1      10  1.02.04  36.418731
# ...       ...            ...          ...     ...      ...        ...
# 1087  npr1_97  npr.1.G1F.972         npr1      97  1.05.16  20.747628
# 1088  npr1_97  npr.1.G2E.971         npr1      97  1.05.16  20.747628
# 1089  npr1_97  npr.1.G2E.972         npr1      97  1.05.16  20.747628
# 1090  npr1_97  npr.1.G2F.971         npr1      97  1.05.16  20.747628
# 1091  npr1_97  npr.1.G2F.972         npr1      97  1.05.16  20.747628
#
#       AT1G01010  AT1G01040  AT1G01046   AT1G01050  ...  BCIN18G00020  \
# 0     39.556340   0.000000   0.000000   21.373592  ...           0.0
# 1     16.918722   0.000000   0.000000  119.029216  ...           0.0
# 2     14.735361   0.000000   0.000000   58.388002  ...           0.0
# 3     10.552052   0.000000   1.000161   19.548414  ...           0.0
# 4     15.229003   0.000000   0.000000   99.136624  ...           0.0
# ...         ...        ...        ...         ...  ...           ...
# 1087   4.210585   0.226497   0.000000   88.664582  ...           0.0
# 1088   3.895372   0.000000   0.000000   18.900222  ...           0.0
# 1089   7.494782   0.000000   0.000000   14.318503  ...           0.0
# 1090   1.965208   0.000000   0.000000   23.361068  ...           0.0
# 1091   4.988623   0.000000   0.866872   21.179064  ...           0.0
#
#       BCIN18G00060  BCIN18G00145  BCIN18G00180  BCIN18G00190  \
# 0         0.000000      0.000000      0.000000      0.000000
# 1         0.000000      0.000000      0.000000      0.000000
# 2         0.000000      0.000000      0.000000      0.000000
# 3         0.000000      0.000000      0.000000      0.000000
# 4        15.577566     32.042486      0.000000     24.233666
# ...            ...           ...           ...           ...
# 1087      4.623277     12.227030      3.334425     16.953341
# 1088      5.101576     16.951453      7.924833     14.651827
# 1089      7.547289     19.236880      3.313311     15.314539
# 1090      1.803102     16.690115      4.551550     37.868097
# 1091      0.000000     13.988056     19.073366     10.579138
#
#       EFBCT00000013145  EFBCT00000013262  EFBCT00000013292  \
# 0            12.438875          0.000000          0.000000
# 1            15.521645          0.000000          0.000000
# 2            76.250891          0.000000          0.000000
# 3            41.388120         73.847835         53.937879
# 4            47.555802          0.000000         54.228767
# ...                ...               ...               ...
# 1087         12.097817          0.000000         13.795366
# 1088         48.519908         11.222415         24.590291
# 1089         42.074248         18.768019         27.416028
# 1090        132.109896        103.127734          0.000000
# 1091        107.261806         43.215895         31.564551
#
#       ENSRNA049512921.T1  ENSRNA049513883.T1
# 0               0.000000            5.321551
# 1               0.000000            0.000000
# 2               0.000000            0.000000
# 3               0.000000            5.059001
# 4               0.000000            0.000000
# ...                  ...                 ...
# 1087            0.000000            0.000000
# 1088            1.537600            0.000000
# 1089            0.642859            3.857151
# 1090            0.000000            0.000000
# 1091            0.000000            2.960537
#
# [1092 rows x 29107 columns]

# %% [markdown]
# ### Features list

# %%
# top defense feature set
f = open("01_AtDefenseGeneList.pkl", 'rb')
features_list = pickle.load(f)
topN = len(features_list) 

feature_title = "Top defense"

f.close()
print("Number of defense genes:", len(features_list))
# Out:
# Number of defense genes: 130

# %%
# save features
df_fs = pd.DataFrame(features_list) 
df_fs.to_csv(f"../results/03_At/features/{nb_long_id}_list_{topN}.csv", header=False, index=False)

# %% [markdown]
# ### Training, validation, and test data

# %%
# load training, validation data
f = open("01_train_test_data.pkl", 'rb')
train_test_data = pickle.load(f)
f.close()

df_X_train = train_test_data['df_X_train']
df_X_train = df_X_train.loc[:,features_list]

df_X_test = train_test_data['df_X_test']
df_X_test = df_X_test.loc[:,features_list]

y_train = train_test_data['y_train']
y_test = train_test_data['y_test']
scaler = train_test_data['scaler']

print(f"Training and validation sets")
print(f"X_train: {np.shape(df_X_train)}")
print(f"X_test: {np.shape(df_X_test)}")
print(f"y_train: {np.shape(y_train)}")
print(f"y_test: {np.shape(y_test)}")

# At Only test data
f = open("01_At_test_data.pkl", 'rb')
df_At_X_test_scaled = pickle.load(f)
f.close()

df_At_X_test_scaled = df_At_X_test_scaled.loc[:,features_list]

print(f"\nTest set")
print(f"At_X_test_scaled: {np.shape(df_At_X_test_scaled)}")

# At-Psy test data
f = open("01_AtPsy_test_data.pkl", 'rb')
df_AtPsy_X_test_scaled = pickle.load(f)
f.close()

df_AtPsy_X_test_scaled = df_AtPsy_X_test_scaled.loc[:,features_list]

print(f"\nAtPsy Test set")
print(f"At_X_test_scaled: {np.shape(df_AtPsy_X_test_scaled)}")

X_train = df_X_train.to_numpy()
X_test = df_X_test.to_numpy()
At_X_test_scaled = df_At_X_test_scaled.to_numpy()
AtPsy_X_test_scaled = df_AtPsy_X_test_scaled.to_numpy()
# Out:
# Training and validation sets
# X_train: (2060, 130)
# X_test: (328, 130)
# y_train: (2060,)
# y_test: (328,)
#
# Test set
# At_X_test_scaled: (6, 130)
#
# AtPsy Test set
# At_X_test_scaled: (100, 130)

# %%
X_train = df_X_train.to_numpy()
X_test = df_X_test.to_numpy()
At_X_test_scaled = df_At_X_test_scaled.to_numpy()

# %% [markdown]
# ## DNN

# %% [markdown]
# Classification accuracy is almost universally inappropriate for imbalanced classification.
#
# For imbalanced classification problems, the *majority class* is typically referred to as the negative outcome (e.g. such as “no change” or “negative test result“), and the *minority class* is typically referred to as the positive outcome (e.g. “change” or “positive test result“).
#
# **Sensitivity-Specificity Metrics** <br>
# Sensitivity = TruePositive / (TruePositive + FalseNegative) *<br>
# Specificity = TrueNegative / (FalsePositive + TrueNegative) <br>
# G-Mean = sqrt(Sensitivity * Specificity)<br>
#
#
#
#
# **Precision-Recall Metrics**<br>
# Precision = TruePositive / (TruePositive + FalsePositive)<br>
# Recall = TruePositive / (TruePositive + FalseNegative)<br>
# F-Measure = (2 * Precision * Recall) / (Precision + Recall) *
#
# ### Train

# %%
model, history = train_dnn_1layer(X_train, y_train, X_test, y_test, num_classes, epochs=50)
# Out:
# Epoch 1/50
# 65/65 [==============================] - 1s 8ms/step - loss: 1.9918 - sparse_categorical_accuracy: 0.2915 - val_loss: 2.1133 - val_sparse_categorical_accuracy: 0.2104
# Epoch 2/50
# 65/65 [==============================] - 0s 1ms/step - loss: 1.2989 - sparse_categorical_accuracy: 0.5616 - val_loss: 2.0614 - val_sparse_categorical_accuracy: 0.2622
# Epoch 3/50
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0636 - sparse_categorical_accuracy: 0.6352 - val_loss: 2.1658 - val_sparse_categorical_accuracy: 0.2195
# Epoch 4/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8614 - sparse_categorical_accuracy: 0.7075 - val_loss: 2.2082 - val_sparse_categorical_accuracy: 0.2500
# Epoch 5/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7554 - sparse_categorical_accuracy: 0.7477 - val_loss: 2.2178 - val_sparse_categorical_accuracy: 0.3018
# Epoch 6/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6729 - sparse_categorical_accuracy: 0.7656 - val_loss: 2.3347 - val_sparse_categorical_accuracy: 0.2500
# Epoch 7/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.6394 - sparse_categorical_accuracy: 0.7873 - val_loss: 2.3830 - val_sparse_categorical_accuracy: 0.2744
# Epoch 8/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5914 - sparse_categorical_accuracy: 0.7968 - val_loss: 2.4412 - val_sparse_categorical_accuracy: 0.2591
# Epoch 9/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5612 - sparse_categorical_accuracy: 0.8068 - val_loss: 2.4436 - val_sparse_categorical_accuracy: 0.2530
# Epoch 10/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.5006 - sparse_categorical_accuracy: 0.8371 - val_loss: 2.5552 - val_sparse_categorical_accuracy: 0.2470
# Epoch 11/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4472 - sparse_categorical_accuracy: 0.8594 - val_loss: 2.5804 - val_sparse_categorical_accuracy: 0.2561
# Epoch 12/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4566 - sparse_categorical_accuracy: 0.8436 - val_loss: 2.6133 - val_sparse_categorical_accuracy: 0.2683
# Epoch 13/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.4034 - sparse_categorical_accuracy: 0.8595 - val_loss: 2.6614 - val_sparse_categorical_accuracy: 0.2591
# Epoch 14/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.3800 - sparse_categorical_accuracy: 0.8689 - val_loss: 2.6919 - val_sparse_categorical_accuracy: 0.2561
# Epoch 15/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.3661 - sparse_categorical_accuracy: 0.8714 - val_loss: 2.7823 - val_sparse_categorical_accuracy: 0.2774
# Epoch 16/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.3921 - sparse_categorical_accuracy: 0.8586 - val_loss: 2.8395 - val_sparse_categorical_accuracy: 0.2683
# Epoch 17/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.3693 - sparse_categorical_accuracy: 0.8712 - val_loss: 2.8383 - val_sparse_categorical_accuracy: 0.2530
# Epoch 18/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.3172 - sparse_categorical_accuracy: 0.9006 - val_loss: 2.8391 - val_sparse_categorical_accuracy: 0.2622
# Epoch 19/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.3325 - sparse_categorical_accuracy: 0.8896 - val_loss: 2.9151 - val_sparse_categorical_accuracy: 0.2835
# Epoch 20/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2767 - sparse_categorical_accuracy: 0.9149 - val_loss: 2.9613 - val_sparse_categorical_accuracy: 0.2683
# Epoch 21/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.9026 - val_loss: 2.9811 - val_sparse_categorical_accuracy: 0.2652
# Epoch 22/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2719 - sparse_categorical_accuracy: 0.9183 - val_loss: 3.0473 - val_sparse_categorical_accuracy: 0.2622
# Epoch 23/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2551 - sparse_categorical_accuracy: 0.9171 - val_loss: 3.1200 - val_sparse_categorical_accuracy: 0.2561
# Epoch 24/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2688 - sparse_categorical_accuracy: 0.9143 - val_loss: 3.1769 - val_sparse_categorical_accuracy: 0.2622
# Epoch 25/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2256 - sparse_categorical_accuracy: 0.9257 - val_loss: 3.2266 - val_sparse_categorical_accuracy: 0.2713
# Epoch 26/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2541 - sparse_categorical_accuracy: 0.9192 - val_loss: 3.2791 - val_sparse_categorical_accuracy: 0.2683
# Epoch 27/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2183 - sparse_categorical_accuracy: 0.9341 - val_loss: 3.3397 - val_sparse_categorical_accuracy: 0.2713
# Epoch 28/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1995 - sparse_categorical_accuracy: 0.9330 - val_loss: 3.3047 - val_sparse_categorical_accuracy: 0.2591
# Epoch 29/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2013 - sparse_categorical_accuracy: 0.9302 - val_loss: 3.3911 - val_sparse_categorical_accuracy: 0.2774
# Epoch 30/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1992 - sparse_categorical_accuracy: 0.9372 - val_loss: 3.4179 - val_sparse_categorical_accuracy: 0.2683
# Epoch 31/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.2104 - sparse_categorical_accuracy: 0.9294 - val_loss: 3.4099 - val_sparse_categorical_accuracy: 0.2470
# Epoch 32/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1900 - sparse_categorical_accuracy: 0.9436 - val_loss: 3.5328 - val_sparse_categorical_accuracy: 0.2744
# Epoch 33/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1784 - sparse_categorical_accuracy: 0.9475 - val_loss: 3.6142 - val_sparse_categorical_accuracy: 0.2530
# Epoch 34/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1900 - sparse_categorical_accuracy: 0.9413 - val_loss: 3.5809 - val_sparse_categorical_accuracy: 0.2713
# Epoch 35/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1926 - sparse_categorical_accuracy: 0.9420 - val_loss: 3.6221 - val_sparse_categorical_accuracy: 0.2591
# Epoch 36/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1670 - sparse_categorical_accuracy: 0.9486 - val_loss: 3.6310 - val_sparse_categorical_accuracy: 0.2683
# Epoch 37/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1797 - sparse_categorical_accuracy: 0.9400 - val_loss: 3.6729 - val_sparse_categorical_accuracy: 0.2744
# Epoch 38/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1507 - sparse_categorical_accuracy: 0.9575 - val_loss: 3.6959 - val_sparse_categorical_accuracy: 0.2805
# Epoch 39/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1373 - sparse_categorical_accuracy: 0.9604 - val_loss: 3.7054 - val_sparse_categorical_accuracy: 0.2774
# Epoch 40/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9515 - val_loss: 3.8194 - val_sparse_categorical_accuracy: 0.2866
# Epoch 41/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1537 - sparse_categorical_accuracy: 0.9507 - val_loss: 3.7327 - val_sparse_categorical_accuracy: 0.2957
# Epoch 42/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1595 - sparse_categorical_accuracy: 0.9432 - val_loss: 3.8886 - val_sparse_categorical_accuracy: 0.2896
# Epoch 43/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1191 - sparse_categorical_accuracy: 0.9614 - val_loss: 3.9096 - val_sparse_categorical_accuracy: 0.2744
# Epoch 44/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1395 - sparse_categorical_accuracy: 0.9586 - val_loss: 3.8550 - val_sparse_categorical_accuracy: 0.2805
# Epoch 45/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1256 - sparse_categorical_accuracy: 0.9591 - val_loss: 3.9263 - val_sparse_categorical_accuracy: 0.2805
# Epoch 46/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1190 - sparse_categorical_accuracy: 0.9654 - val_loss: 3.9006 - val_sparse_categorical_accuracy: 0.2774
# Epoch 47/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1378 - sparse_categorical_accuracy: 0.9549 - val_loss: 3.9896 - val_sparse_categorical_accuracy: 0.2866
# Epoch 48/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1207 - sparse_categorical_accuracy: 0.9594 - val_loss: 4.0117 - val_sparse_categorical_accuracy: 0.2774
# Epoch 49/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1242 - sparse_categorical_accuracy: 0.9604 - val_loss: 4.0109 - val_sparse_categorical_accuracy: 0.2896
# Epoch 50/50
# 65/65 [==============================] - 0s 1ms/step - loss: 0.1091 - sparse_categorical_accuracy: 0.9660 - val_loss: 4.1275 - val_sparse_categorical_accuracy: 0.2835
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 130)               520
# _________________________________________________________________
# flatten (Flatten)            (None, 130)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               67072
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 72,722
# Trainable params: 72,462
# Non-trainable params: 260
# _________________________________________________________________
#
# elapsed time: 0.08 mins

# %% [markdown]
# ### Test1

# %%
# Evaluate performance on Test set1
predictions = model.predict(X_test)
dnn_y_pred = np.argmax(predictions, 1)
dnn_score = get_sk_metrics(y_test, dnn_y_pred)
dnn_cm = plot_confusion_matrix(y_test, dnn_y_pred)

# save the keras model and results
filename = f"./models/{nb_long_id}_dnn_model_f{topN}"
model.save(filename)

filename = f"./models/{nb_long_id}_dnn_results_f{topN}.pkl"
pickle.dump([history.history, dnn_score, dnn_cm], open(filename, 'wb'))
print(f"Written to: {filename}")
# Out:
# Accuracy:	 28.35%
# Precision:	 22.72%
# Recall:		 21.04%
# F1 score:	 21.53%
# INFO:tensorflow:Assets written to: ./models/03a08_defense_dnn_model_f130/assets
# Written to: ./models/03a08_defense_dnn_results_f130.pkl

# %% [markdown]
# ### Test2

# %%
# Evaluate performance on Test set2
predictions = model.predict(At_X_test_scaled)
dnn_y_pred = np.argmax(predictions, 1)

filename = f"../results/03_At/prediction/{nb_long_id}_dnn_test_predict_f{topN}.pkl"
pickle.dump(dnn_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")

dnn_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_dnn_test_predict_f130.pkl
# array([4, 4, 4, 2, 2, 2])

# %% [markdown]
# ### Test3 AtPsy

# %%
# load model and results
filename = f'./models/{nb_long_id}_dnn_model_f{topN}'
print(filename)
model = keras.models.load_model(filename)

filename = f'./models/{nb_long_id}_dnn_results_f{topN}.pkl'
# history, dnn_score, dnn_cm = pickle.load(open(filename,'rb'))

predictions = model.predict(X_test)
dnn_y_pred = np.argmax(predictions, 1)
dnn_score = get_sk_metrics(y_test, dnn_y_pred)
dnn_cm = plot_confusion_matrix(y_test, dnn_y_pred)
# Out:
# ./models/03a08_defense_dnn_model_f130
# Accuracy:	 28.35%
# Precision:	 22.72%
# Recall:		 21.04%
# F1 score:	 21.53%

# %%
X_test_scaled = AtPsy_X_test_scaled

predictions = model.predict(X_test_scaled)
dnn_y_pred = np.argmax(predictions, 1)

filename = f"../results/03_At/prediction/{nb_long_id}_dnn_test_AtPsy_predict_f{topN}.pkl"
pickle.dump(dnn_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")

dnn_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_dnn_test_AtPsy_predict_f130.pkl
# array([5, 0, 5, 0, 5, 5, 5, 5, 5, 5, 0, 0, 5, 5, 5, 0, 0, 0, 0, 0, 5, 5,
#        5, 0, 0, 0, 5, 0, 5, 5, 5, 1, 5, 5, 5, 5, 1, 0, 1, 5, 5, 5, 0, 0,
#        0, 5, 5, 5, 5, 0, 0, 1, 5, 5, 5, 5, 5, 5, 1, 5, 1, 5, 1, 0, 5, 5,
#        5, 0, 5, 5, 5, 1, 5, 5, 5, 5, 5, 5, 3, 0, 5, 3, 0, 5, 5, 3, 1, 0,
#        0, 5, 5, 0, 1, 1, 5, 5, 5, 5, 5, 5])

# %% [markdown]
# ## XGBoost
# XGBoost is an implementation of gradient boosted decision trees designed for speed and performance.
#
# ### Train

# %%
xgb = XGBClassifier()

t0 = time.time()
xgb.fit(X_train, y_train)
t = time.time() - t0

print(f"\nelapsed time: {(t/60):.2f} mins")
print()
# Out:
# [23:06:50] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1607604592557/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/jayson/miniconda3/envs/py38/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# elapsed time: 0.06 mins

# %% [markdown]
# ### Test1

# %%
xgb_y_pred = xgb.predict(X_test)
xgb_score = get_sk_metrics(y_test, xgb_y_pred, average='macro')
xgb_cm = plot_confusion_matrix(y_test, xgb_y_pred)

filename = f"./models/{nb_long_id}_xgb_model_results_f{topN}.pkl"
pickle.dump([xgb, xgb_score, xgb_cm], open(filename, 'wb'))
print(f"Written to: {filename}")
# Out:
# Accuracy:	 29.57%
# Precision:	 22.42%
# Recall:		 22.14%
# F1 score:	 21.98%
# Written to: ./models/03a08_defense_xgb_model_results_f130.pkl

# %% [markdown]
# ### Test2

# %%
xgb_y_pred = xgb.predict(At_X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_xgb_test_predict_f{topN}.pkl"
pickle.dump(xgb_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
xgb_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_xgb_test_predict_f130.pkl
# array([1., 4., 4., 3., 2., 5.])

# %% [markdown]
# ### Test3 AtPsy

# %%
filename = f'./models/{nb_long_id}_xgb_model_results_f{topN}.pkl'
print(filename)
xgb, xgb_score, xgb_cm = pickle.load(open(filename,'rb'))

xgb_y_pred = xgb.predict(X_test)
xgb_score = get_sk_metrics(y_test, xgb_y_pred, average='macro')
xgb_cm = plot_confusion_matrix(y_test, xgb_y_pred)
# Out:
# ./models/03a08_defense_xgb_model_results_f130.pkl
# Accuracy:	 29.57%
# Precision:	 22.42%
# Recall:		 22.14%
# F1 score:	 21.98%

# %%
X_test_scaled = AtPsy_X_test_scaled

xgb_y_pred = xgb.predict(X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_xgb_test_AtPsy_predict_f{topN}.pkl"
pickle.dump(xgb_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
xgb_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_xgb_test_AtPsy_predict_f130.pkl
# array([5., 5., 5., 2., 5., 2., 4., 2., 5., 2., 2., 2., 4., 4., 3., 2., 2.,
#        5., 5., 2., 5., 2., 5., 2., 5., 5., 5., 2., 5., 2., 4., 5., 2., 6.,
#        5., 5., 5., 2., 3., 3., 5., 4., 5., 5., 3., 5., 5., 4., 5., 5., 5.,
#        5., 4., 5., 3., 4., 5., 4., 2., 5., 4., 4., 4., 5., 5., 4., 4., 2.,
#        6., 6., 5., 5., 4., 5., 3., 5., 4., 5., 4., 3., 5., 5., 5., 4., 4.,
#        5., 5., 5., 2., 4., 5., 2., 3., 5., 5., 4., 3., 5., 4., 4.])

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Train

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=30, random_state=0)

t0 = time.time()
rf.fit(X_train, y_train)
t = time.time() - t0

print(f"\nelapsed time: {(t/60):.2f} mins")
print()
# Out:
# elapsed time: 0.02 mins

# %% [markdown]
# ### Test1

# %%
rf_y_pred = rf.predict(X_test)
rf_score = get_sk_metrics(y_test, rf_y_pred, average='macro')
rf_cm = plot_confusion_matrix(y_test, rf_y_pred)

filename = f"./models/{nb_long_id}_rf_model_results_f{topN}.pkl"
pickle.dump([rf, rf_score, rf_cm], open(filename, 'wb'))
print(f"Written to: {filename}")
# Out:
# Accuracy:	 28.05%
# Precision:	 17.96%
# Recall:		 17.61%
# F1 score:	 17.38%
# Written to: ./models/03a08_defense_rf_model_results_f130.pkl

# %% [markdown]
# ### Test2

# %%
rf_y_pred = rf.predict(At_X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_rf_test_predict_f{topN}.pkl"
pickle.dump(rf_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
rf_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_rf_test_predict_f130.pkl
# array([0., 2., 4., 5., 5., 5.])

# %% [markdown]
# ### Test3 AtPsy

# %%
filename = f'./models/{nb_long_id}_rf_model_results_f{topN}.pkl'
print(filename)
rf, rf_score, rf_cm = pickle.load(open(filename,'rb'))

rf_y_pred = rf.predict(X_test)
rf_score = get_sk_metrics(y_test, rf_y_pred, average='macro')
rf_cm = plot_confusion_matrix(y_test, rf_y_pred)
# Out:
# ./models/03a08_defense_rf_model_results_f130.pkl
# Accuracy:	 28.05%
# Precision:	 17.96%
# Recall:		 17.61%
# F1 score:	 17.38%

# %%
X_test_scaled = AtPsy_X_test_scaled
rf_y_pred = rf.predict(X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_rf_test_AtPsy_predict_f{topN}.pkl"
pickle.dump(rf_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
rf_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_rf_test_AtPsy_predict_f130.pkl
# array([4., 3., 1., 2., 4., 4., 4., 2., 1., 1., 4., 2., 4., 1., 4., 1., 4.,
#        1., 1., 1., 5., 4., 4., 1., 1., 1., 4., 2., 4., 4., 2., 2., 2., 4.,
#        8., 4., 4., 1., 4., 4., 1., 4., 2., 2., 4., 4., 2., 4., 4., 2., 2.,
#        2., 4., 4., 4., 4., 2., 4., 2., 4., 4., 4., 4., 4., 6., 4., 4., 1.,
#        4., 4., 4., 4., 4., 4., 8., 1., 4., 4., 4., 1., 4., 5., 1., 4., 4.,
#        5., 3., 2., 2., 4., 4., 1., 4., 4., 4., 4., 4., 1., 5., 4.])

# %% [markdown]
# ## SVM
# ### RBF kernel
# #### Train

# %%
#Create a svm Classifier
svm = SVC() 

t0 = time.time()
svm.fit(X_train, y_train)
t = time.time() - t0

print(f"\nelapsed time: {(t/60):.2f} mins")
print()
# Out:
# elapsed time: 0.01 mins

# %% [markdown]
# #### Test1

# %%
#Predict the response for test dataset
svm_y_pred = svm.predict(X_test)
svm_score = get_sk_metrics(y_test, svm_y_pred, average='macro')
svm_cm = plot_confusion_matrix(y_test, svm_y_pred)

filename = f"./models/{nb_long_id}_svm_model_results_f{topN}.pkl"
pickle.dump([svm, svm_score, svm_cm], open(filename, 'wb'))
print(f"Written to: {filename}")
# Out:
# Accuracy:	 26.52%
# Precision:	 19.80%
# Recall:		 18.15%
# F1 score:	 18.31%
# Written to: ./models/03a08_defense_svm_model_results_f130.pkl

# %% [markdown]
# #### Test2

# %%
#Predict the response for test dataset
svm_y_pred = svm.predict(At_X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_svm_test_predict_f{topN}.pkl"
pickle.dump(svm_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
svm_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_svm_test_predict_f130.pkl
# array([1., 2., 4., 2., 2., 2.])

# %% [markdown]
# ### Test3 AtPsy

# %%
filename = f'./models/{nb_long_id}_svm_model_results_f{topN}.pkl'
print(filename)
svm, svm_score, svm_cm = pickle.load(open(filename,'rb'))

svm_y_pred = svm.predict(X_test)
svm_score = get_sk_metrics(y_test, svm_y_pred, average='macro')
svm_cm = plot_confusion_matrix(y_test, svm_y_pred)
# Out:
# ./models/03a08_defense_svm_model_results_f130.pkl
# Accuracy:	 26.52%
# Precision:	 19.80%
# Recall:		 18.15%
# F1 score:	 18.31%

# %%
X_test_scaled = AtPsy_X_test_scaled
svm_y_pred = svm.predict(X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_svm_test_AtPsy_predict_f{topN}.pkl"
pickle.dump(svm_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
svm_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_svm_test_AtPsy_predict_f130.pkl
# array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#        2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.])

# %% [markdown]
# ### Linear kernel
# #### Train

# %%
#Create a svm Classifier
svm_lin = SVC(kernel='linear') # Linear Kernel

t0 = time.time()
#Train the model using the training sets
svm_lin.fit(X_train, y_train)
t = time.time() - t0

print(f"\nelapsed time: {(t/60):.2f} mins")
print()
# Out:
# elapsed time: 0.01 mins

# %% [markdown]
# #### Test1

# %%
svm_lin_y_pred = svm_lin.predict(X_test)
svm_lin_score = get_sk_metrics(y_test, svm_lin_y_pred, average='macro')
svm_lin_cm = plot_confusion_matrix(y_test, svm_lin_y_pred)

filename = f"./models/{nb_long_id}_svm_lin_model_results_f{topN}.pkl"
pickle.dump([svm_lin, svm_lin_score, svm_lin_cm], open(filename, 'wb'))
print(f"Written to: {filename}")
# Out:
# Accuracy:	 25.91%
# Precision:	 20.74%
# Recall:		 19.57%
# F1 score:	 19.57%
# Written to: ./models/03a08_defense_svm_lin_model_results_f130.pkl

# %% [markdown]
# #### Test2

# %%
svm_lin_y_pred = svm_lin.predict(At_X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_svm_lin_test_predict_f{topN}.pkl"
pickle.dump(svm_lin_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
svm_lin_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_svm_lin_test_predict_f130.pkl
# array([1., 1., 1., 0., 3., 5.])

# %% [markdown]
# ### Test3 AtPsy

# %%
filename = f'./models/{nb_long_id}_svm_lin_model_results_f{topN}.pkl'
print(filename)
svm_lin, svm_lin_score, svm_lin_cm = pickle.load(open(filename,'rb'))

svm_lin_y_pred = svm_lin.predict(X_test)
svm_lin_score = get_sk_metrics(y_test, svm_lin_y_pred, average='macro')
svm_lin_cm = plot_confusion_matrix(y_test, svm_lin_y_pred)
# Out:
# ./models/03a08_defense_svm_lin_model_results_f130.pkl
# Accuracy:	 25.91%
# Precision:	 20.74%
# Recall:		 19.57%
# F1 score:	 19.57%

# %%
X_test_scaled = AtPsy_X_test_scaled

svm_lin_y_pred = svm_lin.predict(X_test_scaled)

filename = f"../results/03_At/prediction/{nb_long_id}_svm_lin_test_AtPsy_predict_f{topN}.pkl"
pickle.dump(svm_lin_y_pred, open(filename, 'wb'))
print(f"Written to: {filename}")
svm_lin_y_pred
# Out:
# Written to: ../results/03_At/prediction/03a08_defense_svm_lin_test_AtPsy_predict_f130.pkl
# array([5., 1., 5., 7., 8., 5., 8., 7., 5., 5., 1., 0., 5., 5., 5., 5., 5.,
#        7., 0., 0., 8., 5., 5., 1., 5., 1., 5., 0., 5., 5., 5., 7., 5., 5.,
#        5., 5., 1., 0., 5., 5., 5., 8., 5., 0., 5., 5., 5., 5., 5., 5., 0.,
#        0., 5., 5., 5., 8., 5., 8., 1., 8., 5., 8., 3., 5., 8., 8., 8., 5.,
#        8., 5., 8., 5., 8., 5., 5., 5., 5., 8., 3., 5., 5., 3., 5., 5., 5.,
#        3., 5., 0., 0., 5., 5., 1., 5., 5., 8., 8., 5., 5., 8., 5.])

# %% [markdown]
# ## Plots
# ### Performance metrics
#
# **Precision** is a measure of the ability of a classification model to identify only the relevant data points.<br>
# **Recall** is a measure of the ability of a model to find all the relevant cases within a dataset.

# %%
max_ylim = 0.5
file_out = f'./figures/{nb_long_id}_score_f{topN}.pdf'
fig_title = 'At only features'
df_metrics = plot_performance_metrics(nb_long_id, max_ylim, file_out, fig_title, feature_size=topN)
df_metrics
# Out:
# Saving to ./figures/03a08_defense_score_f130.pdf
#         Accuracy  Precision    Recall  F1 Score
# DNN     0.283537   0.227211  0.210375  0.215310
# XGB     0.295732   0.224189  0.221354  0.219816
# RF      0.280488   0.179640  0.176118  0.173769
# SVM     0.265244   0.198018  0.181547  0.183062
# linSVM  0.259146   0.207369  0.195710  0.195677

# %% [markdown]
# #### Fuzzy results

# %%
max_ylim = 0.8
offset = 1
file_out = f'./figures/{nb_long_id}_fuzzy_score_f{topN}.pdf'
fig_title = f'At only features (class offset tolerance = {offset})'
df_metrics = plot_performance_metrics(nb_long_id, max_ylim, file_out, fig_title, offset, feature_size=topN)
df_metrics
# Out:
# Saving to ./figures/03a08_defense_fuzzy_score_f130.pdf
#         Accuracy  Precision    Recall  F1 Score
# DNN     0.679878   0.579259  0.581969  0.500453
# XGB     0.673780   0.532614  0.580708  0.548190
# RF      0.685976   0.549025  0.564006  0.534899
# SVM     0.661585   0.518896  0.488133  0.445392
# linSVM  0.649390   0.577091  0.592020  0.559500

# %% [markdown]
# ### MSE

# %%
total_class_mse, class_mse, class_rss = class_error(dnn_cm)
total_class_mse

max_ylim = 3.5
file_out = f'./figures/{nb_long_id}_mse_f{topN}.pdf'
fig_title = f'At only features, class MSE'
df_metrics = plot_mse(nb_long_id, max_ylim, file_out, fig_title, feature_size=topN)
df_metrics
# Out:
# Saving to ./figures/03a08_defense_mse_f130.pdf
#              MSE
# DNN     3.378049
# XGB     3.795732
# RF      3.591463
# SVM     3.567073
# linSVM  4.057927

# %% [markdown]
# ### Test2 prediction summary

# %%
cols = ['DNN', 'XGB', 'RF', 'SVM', 'linSVM']
ml_predictions = np.vstack((dnn_y_pred, xgb_y_pred, rf_y_pred, svm_y_pred, svm_lin_y_pred)).T
df_test2_predict = pd.DataFrame(data=ml_predictions, columns=cols, )

print(f"{nb_long_id} Test Predictions")
filename = f"../results/03_At/prediction/{nb_long_id}_test_predictions_f{topN}.pkl"
pickle.dump(df_test2_predict, open(filename, 'wb'))
print(f"Written to: {filename}")

df_test2_predict
# Out:
# 03a08_defense Test Predictions
# Written to: ../results/03_At/prediction/03a08_defense_test_predictions_f130.pkl
#    DNN  XGB   RF  SVM  linSVM
# 0  4.0  1.0  0.0  1.0     1.0
# 1  4.0  4.0  2.0  2.0     1.0
# 2  4.0  4.0  4.0  4.0     1.0
# 3  2.0  3.0  5.0  2.0     0.0
# 4  2.0  2.0  5.0  2.0     3.0
# 5  2.0  5.0  5.0  2.0     5.0

# %% [markdown]
# ### Test3 prediction summary

# %%
cols = ['DNN', 'XGB', 'RF', 'SVM', 'linSVM']
ml_predictions = np.vstack((dnn_y_pred, xgb_y_pred, rf_y_pred, svm_y_pred, svm_lin_y_pred)).T
df_test3_predict = pd.DataFrame(data=ml_predictions, columns=cols, )

print(f"{nb_long_id} Test Predictions")
filename = f"../results/03_At/prediction/{nb_long_id}_test_AtPsy_predictions_f{topN}.pkl"
pickle.dump(df_test3_predict, open(filename, 'wb'))
print(f"Written to: {filename}")

df_test3_predict
# Out:
# 03a08_defense Test Predictions
# Written to: ../results/03_At/prediction/03a08_defense_test_AtPsy_predictions_f130.pkl
#     DNN  XGB   RF  SVM  linSVM
# 0   5.0  5.0  4.0  2.0     5.0
# 1   0.0  5.0  3.0  2.0     1.0
# 2   5.0  5.0  1.0  2.0     5.0
# 3   0.0  2.0  2.0  2.0     7.0
# 4   5.0  5.0  4.0  2.0     8.0
# ..  ...  ...  ...  ...     ...
# 95  5.0  4.0  4.0  2.0     8.0
# 96  5.0  3.0  4.0  2.0     5.0
# 97  5.0  5.0  1.0  2.0     5.0
# 98  5.0  4.0  5.0  2.0     8.0
# 99  5.0  4.0  4.0  2.0     5.0
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Others

# %%
topN = 130
df = get_prediction_df(nb_long_id, feature_size=topN)
print(f"{nb_long_id}_{topN} Test Predictions")
df
# Out:
# 03a08_defense_130 Test Predictions
#    DNN  XGB   RF  SVM  linSVM
# 0  4.0  1.0  0.0  1.0     1.0
# 1  4.0  4.0  2.0  2.0     1.0
# 2  4.0  4.0  4.0  4.0     1.0
# 3  2.0  3.0  5.0  2.0     0.0
# 4  2.0  2.0  5.0  2.0     3.0
# 5  2.0  5.0  5.0  2.0     5.0
